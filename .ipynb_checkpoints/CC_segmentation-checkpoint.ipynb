# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('customer_segmentation.csv')

# %%
df
# Out:
#        customer_id  age gender  dependent_count education_level  \
# 0        768805383   45      M                3     High School
# 1        818770008   49      F                5        Graduate
# 2        713982108   51      M                3        Graduate
# 3        769911858   40      F                4     High School
# 4        709106358   40      M                3      Uneducated
# ...            ...  ...    ...              ...             ...
# 10122    772366833   50      M                2        Graduate
# 10123    710638233   41      M                2        Graduate
# 10124    716506083   44      F                1     High School
# 10125    717406983   30      M                2        Graduate
# 10126    714337233   43      F                2        Graduate
#
#       marital_status  estimated_income  months_on_book  \
# 0            Married             69000              39
# 1             Single             24000              44
# 2            Married             93000              36
# 3            Unknown             37000              34
# 4            Married             65000              21
# ...              ...               ...             ...
# 10122         Single             51000              40
# 10123       Divorced             40000              25
# 10124        Married             33000              36
# 10125        Unknown             47000              36
# 10126        Married             36000              25
#
#        total_relationship_count  months_inactive_12_mon  credit_limit  \
# 0                             5                       1       12691.0
# 1                             6                       1        8256.0
# 2                             4                       1        3418.0
# 3                             3                       4        3313.0
# 4                             5                       1        4716.0
# ...                         ...                     ...           ...
# 10122                         3                       2        4003.0
# 10123                         4                       2        4277.0
# 10124                         5                       3        5409.0
# 10125                         4                       3        5281.0
# 10126                         6                       2       10388.0
#
#        total_trans_amount  total_trans_count  avg_utilization_ratio
# 0                    1144                 42                  0.061
# 1                    1291                 33                  0.105
# 2                    1887                 20                  0.000
# 3                    1171                 20                  0.760
# 4                     816                 28                  0.000
# ...                   ...                ...                    ...
# 10122               15476                117                  0.462
# 10123                8764                 69                  0.511
# 10124               10291                 60                  0.000
# 10125                8395                 62                  0.000
# 10126               10294                 61                  0.189
#
# [10127 rows x 14 columns]

# %%
df.describe()
# Out:
#         customer_id           age  dependent_count  estimated_income  \
# count  1.012700e+04  10127.000000     10127.000000      10127.000000
# mean   7.391776e+08     46.325960         2.346203      62078.206774
# std    3.690378e+07      8.016814         1.298908      39372.861291
# min    7.080821e+08     26.000000         0.000000      20000.000000
# 25%    7.130368e+08     41.000000         1.000000      32000.000000
# 50%    7.179264e+08     46.000000         2.000000      50000.000000
# 75%    7.731435e+08     52.000000         3.000000      80000.000000
# max    8.283431e+08     73.000000         5.000000     200000.000000
#
#        months_on_book  total_relationship_count  months_inactive_12_mon  \
# count    10127.000000              10127.000000            10127.000000
# mean        35.928409                  3.812580                2.341167
# std          7.986416                  1.554408                1.010622
# min         13.000000                  1.000000                0.000000
# 25%         31.000000                  3.000000                2.000000
# 50%         36.000000                  4.000000                2.000000
# 75%         40.000000                  5.000000                3.000000
# max         56.000000                  6.000000                6.000000
#
#        credit_limit  total_trans_amount  total_trans_count  \
# count  10127.000000        10127.000000       10127.000000
# mean    8631.953698         4404.086304          64.858695
# std     9088.776650         3397.129254          23.472570
# min     1438.300000          510.000000          10.000000
# 25%     2555.000000         2155.500000          45.000000
# 50%     4549.000000         3899.000000          67.000000
# 75%    11067.500000         4741.000000          81.000000
# max    34516.000000        18484.000000         139.000000
#
#        avg_utilization_ratio
# count           10127.000000
# mean                0.274894
# std                 0.275691
# min                 0.000000
# 25%                 0.023000
# 50%                 0.176000
# 75%                 0.503000
# max                 0.999000

# %%
# check for missing data
pd.isna(df).sum()
# Out:
# customer_id                 0
# age                         0
# gender                      0
# dependent_count             0
# education_level             0
# marital_status              0
# estimated_income            0
# months_on_book              0
# total_relationship_count    0
# months_inactive_12_mon      0
# credit_limit                0
# total_trans_amount          0
# total_trans_count           0
# avg_utilization_ratio       0
# dtype: int64

# %%
from pandas.api.types import is_numeric_dtype
numCols = [col for col in df.drop("customer_id", axis=1).columns if is_numeric_dtype(df[col])]

# %%
fig, ax = plt.subplots(figsize=(12, 10))

df.drop('customer_id', axis=1).hist(ax=ax)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_43/677298556.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   df.drop('customer_id', axis=1).hist(ax=ax)

# %%
catCols = [col for col in df.columns if not is_numeric_dtype(df[col])]
catCols
# Out:
# ['gender', 'education_level', 'marital_status']

# %%
df_mod = df.copy()
df_mod['gender'] = df_mod['gender'].apply(lambda x: 1 if x=='M' else 0)

ed_levels = {
    'Uneducated':0,
    'High School':1,
    'College':2,
    'Graduate':3,
    'Post-Graduate':4,
    'Doctorate':5}
df_mod['education_level'] = df_mod['education_level'].apply(lambda x: ed_levels[x])

# %%
df_mod = pd.get_dummies(df_mod, columns=['marital_status'])

# %%
df_mod
# Out:
#        customer_id  age  gender  dependent_count  education_level  \
# 0        768805383   45       1                3                1
# 1        818770008   49       0                5                3
# 2        713982108   51       1                3                3
# 3        769911858   40       0                4                1
# 4        709106358   40       1                3                0
# ...            ...  ...     ...              ...              ...
# 10122    772366833   50       1                2                3
# 10123    710638233   41       1                2                3
# 10124    716506083   44       0                1                1
# 10125    717406983   30       1                2                3
# 10126    714337233   43       0                2                3
#
#        estimated_income  months_on_book  total_relationship_count  \
# 0                 69000              39                         5
# 1                 24000              44                         6
# 2                 93000              36                         4
# 3                 37000              34                         3
# 4                 65000              21                         5
# ...                 ...             ...                       ...
# 10122             51000              40                         3
# 10123             40000              25                         4
# 10124             33000              36                         5
# 10125             47000              36                         4
# 10126             36000              25                         6
#
#        months_inactive_12_mon  credit_limit  total_trans_amount  \
# 0                           1       12691.0                1144
# 1                           1        8256.0                1291
# 2                           1        3418.0                1887
# 3                           4        3313.0                1171
# 4                           1        4716.0                 816
# ...                       ...           ...                 ...
# 10122                       2        4003.0               15476
# 10123                       2        4277.0                8764
# 10124                       3        5409.0               10291
# 10125                       3        5281.0                8395
# 10126                       2       10388.0               10294
#
#        total_trans_count  avg_utilization_ratio  marital_status_Divorced  \
# 0                     42                  0.061                        0
# 1                     33                  0.105                        0
# 2                     20                  0.000                        0
# 3                     20                  0.760                        0
# 4                     28                  0.000                        0
# ...                  ...                    ...                      ...
# 10122                117                  0.462                        0
# 10123                 69                  0.511                        1
# 10124                 60                  0.000                        0
# 10125                 62                  0.000                        0
# 10126                 61                  0.189                        0
#
#        marital_status_Married  marital_status_Single  marital_status_Unknown
# 0                           1                      0                       0
# 1                           0                      1                       0
# 2                           1                      0                       0
# 3                           0                      0                       1
# 4                           1                      0                       0
# ...                       ...                    ...                     ...
# 10122                       0                      1                       0
# 10123                       0                      0                       0
# 10124                       1                      0                       0
# 10125                       0                      0                       1
# 10126                       1                      0                       0
#
# [10127 rows x 17 columns]

# %%
df_scaled = df_mod.drop('customer_id',axis=1)

scaler = StandardScaler()
scaler.fit(df_scaled)
df_scaled = scaler.transform(df_scaled)
df_scaled = pd.DataFrame(df_scaled)

df_scaled
# Out:
#              0         1         2         3         4         5         6   \
# 0     -0.165406  1.059956  0.503368 -0.752211  0.175810  0.384621  0.763943
# 1      0.333570 -0.943436  2.043199  0.662787 -0.967166  1.010715  1.407306
# 2      0.583058  1.059956  0.503368  0.662787  0.785397  0.008965  0.120579
# 3     -0.789126 -0.943436  1.273283 -0.752211 -0.636973 -0.241473 -0.522785
# 4     -0.789126  1.059956  0.503368 -1.459710  0.074212 -1.869317  0.763943
# ...         ...       ...       ...       ...       ...       ...       ...
# 10122  0.458314  1.059956 -0.266547  0.662787 -0.281380  0.509840 -0.522785
# 10123 -0.664382  1.059956 -0.266547  0.662787 -0.560775 -1.368442  0.120579
# 10124 -0.290150 -0.943436 -1.036462 -0.752211 -0.738571  0.008965  0.763943
# 10125 -2.036565  1.059956 -0.266547  0.662787 -0.382978  0.008965  0.120579
# 10126 -0.414894 -0.943436 -0.266547  0.662787 -0.662372 -1.368442  1.407306
#
#              7         8         9         10        11        12        13  \
# 0     -1.327136  0.446622 -0.959707 -0.973895 -0.775882 -0.282405  1.077338
# 1     -1.327136 -0.041367 -0.916433 -1.357340 -0.616276 -0.282405 -0.928214
# 2     -1.327136 -0.573698 -0.740982 -1.911206 -0.997155 -0.282405  1.077338
# 3      1.641478 -0.585251 -0.951758 -1.911206  1.759686 -0.282405 -0.928214
# 4     -1.327136 -0.430877 -1.056263 -1.570365 -0.997155 -0.282405  1.077338
# ...         ...       ...       ...       ...       ...       ...       ...
# 10122 -0.337598 -0.509330  3.259358  2.221481  0.678714 -0.282405 -0.928214
# 10123 -0.337598 -0.479181  1.283475  0.176440  0.856458  3.541013 -0.928214
# 10124  0.651940 -0.354626  1.732994 -0.207005 -0.997155 -0.282405  1.077338
# 10125  0.651940 -0.368710  1.174848 -0.121795 -0.997155 -0.282405 -0.928214
# 10126 -0.337598  0.193220  1.733877 -0.164400 -0.311572 -0.282405  1.077338
#
#              14        15
# 0     -0.798507 -0.282609
# 1      1.252337 -0.282609
# 2     -0.798507 -0.282609
# 3     -0.798507  3.538459
# 4     -0.798507 -0.282609
# ...         ...       ...
# 10122  1.252337 -0.282609
# 10123 -0.798507 -0.282609
# 10124 -0.798507 -0.282609
# 10125 -0.798507  3.538459
# 10126 -0.798507 -0.282609
#
# [10127 rows x 16 columns]

# %%
inertias = []

for k in range(1,11):
    model = KMeans(n_clusters=k)
    clusters = model.fit_predict(df_scaled)
    inertias.append(model.inertia_)

# %%
plt.plot(list(range(1,11)), inertias, marker = 'o')
plt.xlabel('k')
plt.ylabel('Inertia')
plt.show()

# %%
from sklearn.metrics import silhouette_score

silhouettes = []

for k in range(3,8):
    model = KMeans(n_clusters=k)

    X = df_scaled.values
    clusters = model.fit_predict(X)
    silScore = silhouette_score(X, clusters)
    silhouettes.append(silScore)

# %%
model = KMeans(n_clusters=5)
clusters = model.fit_predict(df_scaled)
print(clusters)
# Out:
# [1 4 1 ... 1 0 1]

# %%
df['CLUSTER'] = clusters
for col in numCols:
    c_means = df.groupby('CLUSTER')[col].mean()
    plt.bar(c_means.index, c_means)
    plt.title(col)
    plt.xlabel('Cluster')
    plt.ylabel(f'Mean {col}')
    plt.show()

# %%
focusPairs = [
    ['estimated_income', 'credit_limit'],
    ['estimated_income', 'total_trans_amount'],
    ['estimated_income', 'avg_utilization_ratio'],
    ['credit_limit', 'total_trans_amount'],
    ['credit_limit', 'avg_utilization_ratio']
]

# %%
for pair in focusPairs:
    sns.scatterplot(data=df, x=pair[0], y=pair[1], hue='CLUSTER', palette='tab10')
    plt.show()

# %%
for col in catCols:
    plot_df = pd.crosstab(
        index=df['CLUSTER'], columns=df[col],
      values=df[col], aggfunc='size', normalize='index'
    )
    
    plot_df.columns.name = None
    plot_df.index.name = None
    plot_df.reset_index(drop=False)
    
    plot_df.plot(kind='bar', stacked=True)
